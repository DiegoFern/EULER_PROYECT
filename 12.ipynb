# %% [markdown]
# # Highly divisible triangular number
#
# # Problem 12
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
# ```
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28
# ```
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
from collections import *
from functools import reduce
def number_div_num_tirang(x):
    fact=mult_div_2(Counter(factors(x)),Counter(factors(x)))
    return numb_div_2(fact)
def numb_div_2(d):
    return reduce(lambda x,y:x*y,d.values(),1)-1
def mult_div_2(a,b):
    d = {}
    for x in set(a).union(b):
        d[x] = a.get(x,0)+b.get(x,0)
    d[2]-=1
    return d
def factors(n):
    while n > 1:
        for i in range(2, n + 1):
            if n % i == 0:
                n = n//i
                yield i
                break

# %%
number_div_num_tirang(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-966da68dfac1> in <module>()
# ----> 1 number_div_num_tirang(1)
#
# <ipython-input-15-24a3bd18446e> in number_div_num_tirang(x)
#       2 from functools import reduce
#       3 def number_div_num_tirang(x):
# ----> 4     fact=mult_div_2(Counter(factors(x)),Counter(factors(x)))
#       5     return numb_div_2(fact)
#       6 def numb_div_2(d):
#
# <ipython-input-15-24a3bd18446e> in mult_div_2(a, b)
#      10     for x in set(a).union(b):
#      11         d[x] = a.get(x,0)+b.get(x,0)
# ---> 12     d[2]-=1
#      13     return d
#      14 def factors(n):
#
# KeyError: 2
